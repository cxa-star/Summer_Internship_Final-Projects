# %% [markdown]
# # Mini Project 6 :- ML Feasibility Assessment of Sleep Health and Lifestyle Dataset

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# objective :-
#The objective of Project-6 is to determine whether the selected dataset is suitable for Machine Learning,
#identify the appropriate ML approach, andjustify the feasibility of applying Machine Learning for solving the given problem.

# %%
df = pd.read_csv("Sleep_health_and_lifestyle_dataset.csv")

# %%
df.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# ...

# %%
df.columns
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration',
#        'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
#        'BMI Category', 'Blood Pressure', 'Heart Rate', 'Daily Steps',
#        'Sleep Disorder'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
df.shape
# Out:
# (374, 13)

# %%
df.describe()
# Out:
#         Person ID         Age  Sleep Duration  Quality of Sleep  \
# count  374.000000  374.000000      374.000000        374.000000
# mean   187.500000   42.184492        7.132086          7.312834
# std    108.108742    8.673133        0.795657          1.196956
# min      1.000000   27.000000        5.800000          4.000000
# 25%     94.250000   35.250000        6.400000          6.000000
# 50%    187.500000   43.000000        7.200000          7.000000
# 75%    280.750000   50.000000        7.800000          8.000000
# max    374.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count               374.000000    374.000000  374.000000    374.000000
# mean                 59.171123      5.385027   70.165775   6816.844920
# std                  20.830804      1.774526    4.135676   1617.915679
# min                  30.000000      3.000000   65.000000   3000.000000
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Person ID                    0
# Gender                       0
# Age                          0
# Occupation                   0
# Sleep Duration               0
# Quality of Sleep             0
# Physical Activity Level      0
# Stress Level                 0
# BMI Category                 0
# Blood Pressure               0
# Heart Rate                   0
# Daily Steps                  0
# Sleep Disorder             219
# dtype: int64

# %%
df["Sleep Disorder"] = df["Sleep Disorder"].fillna("undecidable")

# %%
df.isnull().sum()
# Out:
# Person ID                  0
# Gender                     0
# Age                        0
# Occupation                 0
# Sleep Duration             0
# Quality of Sleep           0
# Physical Activity Level    0
# Stress Level               0
# BMI Category               0
# Blood Pressure             0
# Heart Rate                 0
# Daily Steps                0
# Sleep Disorder             0
# dtype: int64

# %%
# Target variable Sleep Disorder ke labels dekhne ke liye
print(df["Sleep Disorder"].value_counts())
# Out:
# Sleep Disorder
# undecidable    219
# Sleep Apnea     78
# Insomnia        77
# Name: count, dtype: int64

# %%
# Unique labels dekhne ke liye

print(df["Sleep Disorder"].unique())
# Out:
# ['undecidable' 'Sleep Apnea' 'Insomnia']

# %% [markdown]
# # Numerical & Categorical Features

# %%
# Numerical columns identify karne ke liye
print("Numerical Columns")
print(df.select_dtypes(include=["int64","float64"]).columns)

# Categorical columns identify karne ke liye
print("\nCategorical Columns")
print(df.select_dtypes(include=["object"]).columns)
# Out:
# Numerical Columns
# Index(['Person ID', 'Age', 'Sleep Duration', 'Quality of Sleep',
#        'Physical Activity Level', 'Stress Level', 'Heart Rate', 'Daily Steps'],
#       dtype='object')
#
# Categorical Columns
# Index(['Gender', 'Occupation', 'BMI Category', 'Blood Pressure',
#        'Sleep Disorder'],
#       dtype='object')

# %%
# Blood Pressure ko Systolic aur Diastolic me split kar rahe hain
df[['Systolic', 'Diastolic']] = df['Blood Pressure'].str.split('/', expand=True)

# String ko integer me convert kar rahe hain
df['Systolic'] = df['Systolic'].astype(int)
df['Diastolic'] = df['Diastolic'].astype(int)

# Original Blood Pressure column remove kar rahe hain
df.drop('Blood Pressure', axis=1, inplace=True)

# %% [markdown]
# # ML Approach Identification

# %%
# Output categories me hai..... None, Insomnia, Sleep Apnea

# Isliye Classification.

# %%
# ML approach identify karne ke liye

target = df["Sleep Disorder"]
print("Unique Labels :")
print(target.unique())
print("Suitable ML Approach : Classification")
# Out:
# Unique Labels :
# ['undecidable' 'Sleep Apnea' 'Insomnia']
# Suitable ML Approach : Classification

# %%
# Final conclusion print karne ke liye

print("""
==========================================
ML FEASIBILITY ASSESSMENT
==========================================

1. Dataset is structured.
2. Dataset contains sufficient records.
3. Target variable is available.
4. Labels are clearly defined.
5. Missing values are minimal or absent.
6. Features are relevant for prediction.

Conclusion:
Machine Learning is FEASIBLE on this dataset.

Recommended ML Approach:
CLASSIFICATION

Reason:
The target variable 'Sleep Disorder'
contains categorical labels such as
None, Insomnia and Sleep Apnea.
==========================================
""")
# Out:
# ...
# ML FEASIBILITY ASSESSMENT
# ...
#
# 1. Dataset is structured.
# 2. Dataset contains sufficient records.
# 3. Target variable is available.
# 4. Labels are clearly defined.
# 5. Missing values are minimal or absent.
# 6. Features are relevant for prediction.
#
# Conclusion:
# Machine Learning is FEASIBLE on this dataset.
#
# Recommended ML Approach:
# CLASSIFICATION
#
# Reason:
# The target variable 'Sleep Disorder'
# contains categorical labels such as
# None, Insomnia and Sleep Apnea.
# ...

# %% [markdown]
# # Label Encoding :-

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df["Gender"] = le.fit_transform(df["Gender"])
df["Occupation"] = le.fit_transform(df["Occupation"])
df["BMI Category"] = le.fit_transform(df["BMI Category"])
df["Sleep Disorder"] = le.fit_transform(df["Sleep Disorder"])

X = df.drop("Sleep Disorder", axis=1)

Y = df["Sleep Disorder"]

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y,test_size=0.2,random_state=42)

# %% [markdown]
# # Decision Tree Classifier :-

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()
model.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# # Accuracy :-

# %%
from sklearn.metrics import accuracy_score

y_pred = model.predict(X_test)
print("Accuracy :", accuracy_score(Y_test, y_pred))
# Out:
# Accuracy : 0.9066666666666666
